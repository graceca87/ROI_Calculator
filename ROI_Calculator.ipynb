# %%
# # Four Square Method:
# ***********************
# Box 1: Income:

# types:  
#     rental: $2000
#     laundry:
#     storage:
#     miscellaneous:

#     Total monthly income = sum of Income

# ***********************
# Box 2: Expenses:

# types: 
#     Taxes/mo: 150
#     Insurance: 100
#     Utilities: 0
#         electric:
#         water:
#         sewer:
#         gas:
#         garbage:
#     HOA: 0 
#     Lawn/Snow: 0
#     Vacancy: 100/mo
#     Repairs: 100
#     Capital Expenditures/ CapEx (big items, replacing things) 100/mo
#     Property Management: 200 (10% of rent)
#     Mortgage: 1000
    
#     Total Expenses = sum of Expenses


# ************************************
# Box 3: Total Monthly Cash Flow 

# TMCF = Total Monthly Icome - Total Expenses

# ************************************
# Box 4: Investment

# Down Payment: 
# Closing Costs:
# Rehab Budge:
# Misc:

# Total Investment = sum of Investment

# *****************************************
# calculate: 

# TMCF * 12 = annual cash flow

# Annual Cash Flow / Total Investment = Cash on Cash ROI (%)

# *****************************************

# Input is integers representing costs
# Output is a float representing the percentage of ROI

# income = sum_of_income
# expenses = sum_of_expenses
# investment = sum_of_investment

# TMCF = income - expenses
# annual_CF = TMCF * 12
# ROI = annual_CF / investment

# I need to create a property class with methods that will ask for inputs and calculate the total

class Property():

    def __init__(self, property):
        self.address = property

    # corrects for invalid answers on yes or no questions. Keeps looping until user types Y or N.
    def _confirm_valid_input_alpha(self,answer):
        while answer not in ["Y".lower(),"N".lower()]:
            answer = input(f"Sorry, I didn't understand that. Please type 'Y' for yes or 'n' for no.").lower()
        else:
            return answer

     # corrects for invalid answers on questions that require a numerical answer. Keeps looping until user types a number.
    def _confirm_input_int(self, answer):
        while answer.isalpha():
            answer = input(f"Sorry, I didn't understand that. Please type a number. For example, type '50' instead of 'fifty'.").lower()
        else: 
    # If the user enters a comma we don't want it to cause an error. We'll remove it here:
            answer_without_commas = answer.replace(",","")
        #convert to a float to account for any cent amounts entered
            return float(answer_without_commas)

    def calculate_income(self):
        rental = input(f"How much would you like to charge for monthly rent?: $") 
        #calling the _confirm_input_int method after each input to make sure the user enters a number.
        rental = self._confirm_input_int(rental)
        laundry = input(f"How much do you want to charge for laundry?: $")
        laundry = self._confirm_input_int(laundry)
        storage = input(f"How much do you want to charge for storage?: $")
        storage = self._confirm_input_int(storage)
        parking = input(f"How much do you want to charge for parking?: $")
        parking = self._confirm_input_int(parking)
        misc = input(f"How much do you want to charge for miscellaneous expenses?: $")
        misc = self._confirm_input_int(misc)
        #     Total monthly income = sum of Income
        self.total_income = rental + laundry + storage + parking + misc
        # print(f"Your total monthly income is: ${self.total_income:.2f}")
        return self.total_income


    def calculate_expenses(self):
        taxes = input(f"How much are the taxes per month?: ")
        taxes = self._confirm_input_int(taxes)
        insurance = input(f"How much is homeowner's insurance per month?: ")
        insurance = self._confirm_input_int(insurance)
        utilities = input(f"Do you pay for the utilities?: Y/n")
        utilities = self._confirm_valid_input_alpha(utilities)
        if utilities == "Y".lower():
            utilities = self._calculate_utilities()
        elif utilities == "N".lower():
            utilities = 0
        hoa = (input(f"Is this property part of a homeowner's association?: Y/n "))
        if hoa == "Y".lower():
            hoa = int(input(f"How much are the monthly HOA fees?: $"))
        else:
            hoa = 0
        outdoor_maint =input(f"Do you take care of outdoor maintenance, such as lawnmowing and snow removal?: Y/n")
        if outdoor_maint == "Y".lower():
            outdoor_maint = input(f"How much is the monthly cost?: $")
        else:
            hoa = 0
        vacancy =input(f"How much are the taxes per month?: ")
        repairs =input(f"How much are the taxes per month?: ")
        # Capital Expeditures (cap_ex) = big items, replacing things like roof
        cap_ex = input(f"How much are the taxes per month?: ")
        #property management is 10% of rent
        prop_mgmt = input(f"How much are the taxes per month?: ")
        mortgage = input(f"How much are the taxes per month?: ")
        expenses = [taxes, insurance, utilities, hoa, outdoor_maint, vacancy, repairs, cap_ex, prop_mgmt, mortgage]
        self.total_expenses = sum(expenses)
        return self.total_expenses
    
    # hiddent function calculates utility amounts only if the landlord says that they cover them.
    def _calculate_utilities(self):
        electric = int(input(f"Approximately how much is the electric bill per month?: "))
        water = int(input(f"Approximately how much is the water bill per month?: "))
        gas = int(input(f"Approximately how much is the gas bill per month?: "))
        garbage = int(input(f"Approximately how much is garbage collection per month?: "))
        self.total_utilities = electric + water + gas + garbage
        return self.total_utilities

property = Property("15 brier lane")
# property.calculate_income()
property.calculate_expenses()

#     Total = sum of Expenses

# Box 3: Total Monthly Cash Flow 
# TMCF = total income - total expenses


# Box 4: Cash on Cash ROI

# Down Payment: 
# Closing Costs:
# Rehab Budge:
# Misc:
# Total Investment = sum of Cash on Cash ROI


# calculate: 

# cash flow * 12 = annual cash flow

# annual cash flow / total investment = Cash on Cash ROI (%)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb Cell 1 in <cell line: 155>()
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=152'>153</a> property = Property("15 brier lane")
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=153'>154</a> # property.calculate_income()
# --> <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=154'>155</a> property.calculate_expenses()
#
# /Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb Cell 1 in Property.calculate_expenses(self)
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=117'>118</a> utilities = self._confirm_valid_input_alpha(utilities)
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=118'>119</a> if utilities == "Y".lower():
# --> <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=119'>120</a>     utilities = self._calculate_utilities()
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=120'>121</a> elif utilities == "N".lower():
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=121'>122</a>     utilities = 0
#
# /Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb Cell 1 in Property._calculate_utilities(self)
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=144'>145</a> def _calculate_utilities(self):
# --> <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=145'>146</a>     electric = int(input(f"Approximately how much is the electric bill per month?: "))
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=146'>147</a>     water = int(input(f"Approximately how much is the water bill per month?: "))
#     <a href='vscode-notebook-cell:/Users/Grace/Documents/CT_Projects/ROI/ROI_Calculator.ipynb#ch0000000?line=147'>148</a>     gas = int(input(f"Approximately how much is the gas bill per month?: "))
#
# ValueError: invalid literal for int() with base 10: '34.00'
